# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Short Summary
#
# In this file we have just quickly taken a look at the 10 items with the most appearances in our data and then looked at how much of said clothes is discarded for each reason.

# %%
folder = Path(
    "/Users/kristianbraad/Library/CloudStorage/OneDrive-Aarhusuniversitet/"
    "4. Semester/Dataprojekt/Dataprojekt AU 2026/2023 AAR vaskeri data"
)
files = list(folder.glob("PLC*.xlsx"))            # matches PLC, Product....xlsx etc.

dfs = []
for f in files:
    df = pd.read_excel(f, header=2)                         # optionally: sheet_name="Sheet1"
    df["source_file"] = f.name                    # helpful traceability
    dfs.append(df)

all_data = pd.concat(dfs, ignore_index=True)
group_col = "Produkt - Produkt"

groups = {gid: gdf.copy() for gid, gdf in all_data.groupby(group_col, dropna=False)}

# Grouping
groups = {k: g.copy() for k, g in all_data.groupby(group_col, dropna=False)}

# %%
summary = (
    all_data
    .groupby(["Produkt - Produkt", "Kassationsårsag (ui)"])["Stk. tøj per kassationsdato"]
    .sum()
    .reset_index()
)
print(summary)
# Out:
#                        Produkt - Produkt                 Kassationsårsag (ui)  \
# 0       00066 Kokkejakke Sort Lechef P/B            Misligholdt med restværdi
# 1     00100 Unisexben Lårl & Toml Mblåpb              Alm.slid uden restværdi
# 2     00100 Unisexben Lårl & Toml Mblåpb              BTS fejl uden restværdi
# 3     00100 Unisexben Lårl & Toml Mblåpb             Bortkommet med restværdi
# 4     00100 Unisexben Lårl & Toml Mblåpb                       Fejlopmærkning
# ...                                  ...                                  ...
# 6011   35040 Benkl Da M/Ela 2 Lom HV P/B  Ødelagt af lommefyld uden restværdi
# 6012    35057 Test shorts Aarhus Kommune              Alm.slid uden restværdi
# 6013    35057 Test shorts Aarhus Kommune             Bortkommet med restværdi
# 6014    35057 Test shorts Aarhus Kommune                         Udgået Model
# 6015    35134 Forklæde recycled JTK sort              BTS fejl uden restværdi
#
#       Stk. tøj per kassationsdato
# 0                               2
# 1                             222
# 2                             144
# 3                               8
# 4                               1
# ...                           ...
# 6011                            2
# 6012                            1
# 6013                            2
# 6014                           11
# 6015                            5
#
# [6016 rows x 3 columns]

# %%
most_discarded = (
    all_data
    .groupby("Produkt - Produkt")["Stk. tøj per kassationsdato"]
    .sum()
    .sort_values(ascending=False)
)

most_discarded.head(10)
# Out:
# Produkt - Produkt
# 09385 T-Shirt Hvid B/P M Arla Tryk    7200
# 23191 Benkl Mind pullon m opsmøg      7064
# 01083 T-Shirt unisex hvid k/æ P/B     6779
# 01589 T-shirt unisex mblå k/æ         6696
# 13084 T-shirt prowear dame navy pb    6152
# 14152 Benkl m/lom hvid low risk       5062
# 28793 Benkl M/Lom Grå Low Risk        4435
# 12143 Pull on let buks opsmøg mblå    4256
# 24781 Flex buks da CSR dark rock      4164
# 09813 T-Shirt Vask                    3781
# Name: Stk. tøj per kassationsdato, dtype: int64

# %% [markdown]
# # Pie charts for 10 biggest datasets

# %% [markdown]
# ## 1.

# %%
product_name = "09385 T-Shirt Hvid B/P M Arla Tryk"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                   1739
# BTS fejl uden restværdi                    845
# Beholdningsnedskrivning uden restværdi       1
# Fejlopmærkning                              15
# Kass. af RETUR,MINIMU,afmeld               348
# Misligeholdt pga blæk                      578
# Misligholdt med restværdi                 3625
# Udgået Model                                45
# Videresalg med RESTVÆRDI                     3
# Ødelagt af lommefyld med restværdi           1
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                      Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                 Alm.slid uden restværdi             1516.085303
# 1                 BTS fejl uden restværdi              954.063905
# 2  Beholdningsnedskrivning uden restværdi               56.000000
# 3                          Fejlopmærkning              285.066667
# 4            Kass. af RETUR,MINIMU,afmeld             1444.741379
# 5                   Misligeholdt pga blæk             1049.669550
# 6               Misligholdt med restværdi             1550.498207
# 7                            Udgået Model              904.755556
# 8                Videresalg med RESTVÆRDI              715.333333
# 9      Ødelagt af lommefyld med restværdi              918.000000
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                    1514.992524       68.814409              68.824037
# 1                     954.063905       25.478107              25.478107
# 2                      56.000000        0.000000               0.000000
# 3                     285.066667       13.400000              13.400000
# 4                    1444.741379       41.755747              41.755747
# 5                    1049.669550       45.321799              45.321799
# 6                    1550.498207       68.208000              68.208000
# 7                     904.755556       33.244444              33.244444
# 8                     715.333333       39.666667              39.666667
# 9                     918.000000       34.000000              34.000000
#
#    Antal kasseret
# 0          1739.0
# 1           845.0
# 2             1.0
# 3            15.0
# 4           348.0
# 5           578.0
# 6          3625.0
# 7            45.0
# 8             3.0
# 9             1.0

# %% [markdown]
# ## 2.

# %%
product_name = "23191 Benkl Mind pullon m opsmøg"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]
plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                4295
# BTS fejl uden restværdi                 648
# Bortkommet med restværdi               1605
# Misligeholdt pga blæk                     2
# Misligholdt med restværdi                 3
# Produktfejl                               6
# Udgået Model                            478
# Ødelagt af lommefyld med restværdi        8
# Ødelagt af lommefyld uden restværdi      19
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                   Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0              Alm.slid uden restværdi             1128.887052
# 1              BTS fejl uden restværdi             1311.288580
# 2             Bortkommet med restværdi             1108.887850
# 3                Misligeholdt pga blæk              317.000000
# 4            Misligholdt med restværdi              615.000000
# 5                          Produktfejl             1426.166667
# 6                         Udgået Model             1145.673640
# 7   Ødelagt af lommefyld med restværdi              823.375000
# 8  Ødelagt af lommefyld uden restværdi             1337.157895
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                    1128.693597       43.437354              43.431432
# 1                    1311.288580       36.635802              36.635802
# 2                    1108.887850       26.009346              26.009346
# 3                     317.000000       13.000000              13.000000
# 4                     615.000000       17.000000              17.000000
# 5                    1426.166667       41.333333              41.333333
# 6                    1145.673640       37.797071              37.797071
# 7                     823.375000       31.750000              31.750000
# 8                    1337.157895       56.631579              56.631579
#
#    Antal kasseret
# 0          4295.0
# 1           648.0
# 2          1605.0
# 3             2.0
# 4             3.0
# 5             6.0
# 6           478.0
# 7             8.0
# 8            19.0

# %% [markdown]
# ## 3.

# %%
product_name = "01083 T-Shirt unisex hvid k/æ P/B"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                   2185
# BTS fejl uden restværdi                    679
# Beholdningsnedskrivning uden restværdi      67
# Bortkommet med restværdi                   157
# Fejlopmærkning                               5
# Kass. af RETUR,MINIMU,afmeld               425
# Misligeholdt pga blæk                      194
# Misligholdt med restværdi                 2194
# Udgået Model                               826
# Videresalg til kunder                       37
# Ødelagt af lommefyld uden restværdi         10
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                       Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                  Alm.slid uden restværdi              958.923112
# 1                  BTS fejl uden restværdi             1256.124260
# 2   Beholdningsnedskrivning uden restværdi             1789.716418
# 3                 Bortkommet med restværdi              573.038217
# 4                           Fejlopmærkning               92.800000
# 5             Kass. af RETUR,MINIMU,afmeld             2197.105882
# 6                    Misligeholdt pga blæk              728.974227
# 7                Misligholdt med restværdi              874.586144
# 8                             Udgået Model              945.090799
# 9                    Videresalg til kunder                0.000000
# 10     Ødelagt af lommefyld uden restværdi             1637.800000
#
#     Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                      958.923112       54.491533              54.491533
# 1                     1250.575847       36.485207              36.324006
# 2                     1789.716418       58.044776              58.044776
# 3                      573.038217        7.414013               7.414013
# 4                       92.800000        5.600000               5.600000
# 5                     2197.105882       30.249412              30.249412
# 6                      728.974227       38.762887              38.762887
# 7                      874.586144       46.887876              46.887876
# 8                      945.090799       33.355932              33.355932
# 9                        0.000000        0.000000               0.000000
# 10                    1637.800000       79.900000              79.900000
#
#     Antal kasseret
# 0           2185.0
# 1            679.0
# 2             67.0
# 3            157.0
# 4              5.0
# 5            425.0
# 6            194.0
# 7           2194.0
# 8            826.0
# 9             37.0
# 10            10.0

# %% [markdown]
# ## 4.

# %%
product_name = "01589 T-shirt unisex mblå k/æ"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                   1867
# BTS fejl uden restværdi                    485
# Beholdningsnedskrivning uden restværdi       3
# Bortkommet med restværdi                   813
# Kass. af RETUR,MINIMU,afmeld              1336
# Misligeholdt pga blæk                       18
# Misligholdt med restværdi                 1513
# Udgået Model                               646
# Videresalg til kunder                        3
# Ødelagt af lommefyld med restværdi           1
# Ødelagt af lommefyld uden restværdi         11
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                       Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                  Alm.slid uden restværdi             1216.686327
# 1                  BTS fejl uden restværdi             1110.989691
# 2   Beholdningsnedskrivning uden restværdi              881.333333
# 3                 Bortkommet med restværdi              906.188192
# 4             Kass. af RETUR,MINIMU,afmeld             2013.677395
# 5                    Misligeholdt pga blæk             1580.500000
# 6                Misligholdt med restværdi             1268.682750
# 7                             Udgået Model              952.018576
# 8                    Videresalg til kunder               37.666667
# 9       Ødelagt af lommefyld med restværdi              656.000000
# 10     Ødelagt af lommefyld uden restværdi              868.181818
#
#     Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                     1215.597215       45.560858              45.515265
# 1                     1110.989691       17.847423              17.847423
# 2                      881.333333       33.666667              33.666667
# 3                      906.188192       19.036900              19.036900
# 4                     2013.677395       20.234281              20.234281
# 5                     1580.500000       60.166667              60.166667
# 6                     1268.682750       38.890284              38.890284
# 7                      952.018576       21.171827              21.171827
# 8                       37.666667        0.666667               0.666667
# 9                      656.000000       30.000000              30.000000
# 10                     868.181818       35.545455              35.545455
#
#     Antal kasseret
# 0           1867.0
# 1            485.0
# 2              3.0
# 3            813.0
# 4           1336.0
# 5             18.0
# 6           1513.0
# 7            646.0
# 8              3.0
# 9              1.0
# 10            11.0

# %% [markdown]
# ## 5.

# %%
product_name = "13084 T-shirt prowear dame navy pb"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                3279
# BTS fejl uden restværdi                 486
# Bortkommet med restværdi               1785
# Kass. af RETUR,MINIMU,afmeld             18
# Misligeholdt pga blæk                     3
# Misligholdt med restværdi                62
# Udgået Model                            490
# Videresalg til andre BTS afdelinger       6
# Ødelagt af lommefyld med restværdi       10
# Ødelagt af lommefyld uden restværdi      13
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                   Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0              Alm.slid uden restværdi              990.093016
# 1              BTS fejl uden restværdi              619.135802
# 2             Bortkommet med restværdi             1083.663866
# 3         Kass. af RETUR,MINIMU,afmeld              717.611111
# 4                Misligeholdt pga blæk              382.666667
# 5            Misligholdt med restværdi              688.951613
# 6                         Udgået Model              648.891837
# 7  Videresalg til andre BTS afdelinger              271.333333
# 8   Ødelagt af lommefyld med restværdi              953.500000
# 9  Ødelagt af lommefyld uden restværdi             1091.923077
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                     990.093016       44.665752              44.665752
# 1                     619.135802       12.648148              12.648148
# 2                    1083.663866       24.728852              24.728852
# 3                     717.611111        9.666667               9.666667
# 4                     382.666667       15.666667              15.666667
# 5                     688.951613       21.580645              21.580645
# 6                     648.891837       27.191837              27.191837
# 7                     271.333333        4.166667               4.166667
# 8                     953.500000       31.700000              31.700000
# 9                    1091.923077       44.384615              44.384615
#
#    Antal kasseret
# 0          3279.0
# 1           486.0
# 2          1785.0
# 3            18.0
# 4             3.0
# 5            62.0
# 6           490.0
# 7             6.0
# 8            10.0
# 9            13.0

# %% [markdown]
# ## 6.

# %%
product_name = "14152 Benkl m/lom hvid low risk"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                    933
# BTS fejl uden restværdi                   1130
# Beholdningsnedskrivning uden restværdi       8
# Fejlopmærkning                               1
# Kass. af RETUR,MINIMU,afmeld               197
# Misligeholdt pga blæk                      805
# Misligholdt med restværdi                 1583
# Produktfejl                                  1
# Udgået Model                               347
# Videresalg til andre BTS afdelinger         57
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                      Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                 Alm.slid uden restværdi             1414.959271
# 1                 BTS fejl uden restværdi             2058.752212
# 2  Beholdningsnedskrivning uden restværdi             2124.875000
# 3                          Fejlopmærkning              989.000000
# 4            Kass. af RETUR,MINIMU,afmeld             1369.218274
# 5                   Misligeholdt pga blæk             1147.154037
# 6               Misligholdt med restværdi             1155.950095
# 7                             Produktfejl             2059.000000
# 8                            Udgået Model              753.809798
# 9     Videresalg til andre BTS afdelinger              132.035088
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                    1414.959271       70.366559              70.366559
# 1                    2058.752212       40.780531              40.780531
# 2                    2124.875000       80.625000              80.625000
# 3                     989.000000       42.000000              42.000000
# 4                    1369.218274       38.781726              38.781726
# 5                    1147.154037       61.029814              61.029814
# 6                    1155.950095       55.894504              55.894504
# 7                    2059.000000      118.000000             118.000000
# 8                     753.809798       29.827089              29.827089
# 9                     132.035088        2.192982               2.192982
#
#    Antal kasseret
# 0           933.0
# 1          1130.0
# 2             8.0
# 3             1.0
# 4           197.0
# 5           805.0
# 6          1583.0
# 7             1.0
# 8           347.0
# 9            57.0

# %% [markdown]
# ## 7.

# %%
product_name = "28793 Benkl M/Lom Grå Low Risk"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                    141
# BTS fejl uden restværdi                   1344
# Beholdningsnedskrivning uden restværdi       2
# Fejlopmærkning                               9
# Kass. af RETUR,MINIMU,afmeld                74
# Misligeholdt pga blæk                     1057
# Misligholdt med restværdi                  426
# Produktfejl                               1248
# Udgået Model                               134
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                      Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                 Alm.slid uden restværdi              173.808511
# 1                 BTS fejl uden restværdi               50.250744
# 2  Beholdningsnedskrivning uden restværdi              261.000000
# 3                          Fejlopmærkning              258.555556
# 4            Kass. af RETUR,MINIMU,afmeld              418.810811
# 5                   Misligeholdt pga blæk              288.822138
# 6               Misligholdt med restværdi              272.089202
# 7                             Produktfejl              338.645032
# 8                            Udgået Model              231.390977
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                     173.808511       10.546099              10.546099
# 1                      50.250744        1.108631               1.108631
# 2                     261.000000        5.500000               5.500000
# 3                     258.555556       12.111111              12.111111
# 4                     418.810811        6.959459               6.959459
# 5                     288.822138       14.838221              14.838221
# 6                     272.089202       12.812207              12.812207
# 7                     338.645032        9.264423               9.264423
# 8                     230.992537        9.315789               9.402985
#
#    Antal kasseret
# 0           141.0
# 1          1344.0
# 2             2.0
# 3             9.0
# 4            74.0
# 5          1057.0
# 6           426.0
# 7          1248.0
# 8           134.0

# %% [markdown]
# ## 8.

# %%
product_name = "12143 Pull on let buks opsmøg mblå"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]


plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                   2022
# BTS fejl uden restværdi                    267
# Beholdningsnedskrivning uden restværdi       2
# Bortkommet med restværdi                   265
# Fejlopmærkning                               1
# Kass. af RETUR,MINIMU,afmeld                47
# Misligholdt med restværdi                   12
# Udgået Model                              1633
# Ødelagt af lommefyld uden restværdi          7
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                      Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                 Alm.slid uden restværdi             1325.491592
# 1                 BTS fejl uden restværdi             1528.453184
# 2  Beholdningsnedskrivning uden restværdi             1406.000000
# 3                Bortkommet med restværdi             1168.935849
# 4                          Fejlopmærkning              821.000000
# 5            Kass. af RETUR,MINIMU,afmeld             1789.638298
# 6               Misligholdt med restværdi             1383.666667
# 7                            Udgået Model             1624.867116
# 8     Ødelagt af lommefyld uden restværdi             1168.428571
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                    1325.491592       63.475767              63.475767
# 1                    1528.453184       47.872659              47.872659
# 2                    1406.000000       77.500000              77.500000
# 3                    1168.935849       39.822642              39.822642
# 4                     821.000000       47.000000              47.000000
# 5                    1789.638298       42.872340              42.872340
# 6                    1383.666667       49.333333              49.333333
# 7                    1624.867116       68.592774              68.592774
# 8                    1168.428571       81.000000              81.000000
#
#    Antal kasseret
# 0          2022.0
# 1           267.0
# 2             2.0
# 3           265.0
# 4             1.0
# 5            47.0
# 6            12.0
# 7          1633.0
# 8             7.0

# %% [markdown]
# ## 9.

# %%
product_name = "24781 Flex buks da CSR dark rock"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi                   3147
# BTS fejl uden restværdi                     21
# Beholdningsnedskrivning uden restværdi       1
# Bortkommet med restværdi                   597
# Misligeholdt pga blæk                        3
# Misligholdt med restværdi                   20
# Udgået Model                               336
# Ødelagt af lommefyld med restværdi           1
# Ødelagt af lommefyld uden restværdi         38
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                      Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0                 Alm.slid uden restværdi              997.778837
# 1                 BTS fejl uden restværdi              597.238095
# 2  Beholdningsnedskrivning uden restværdi               81.000000
# 3                Bortkommet med restværdi              754.695142
# 4                   Misligeholdt pga blæk              435.666667
# 5               Misligholdt med restværdi              958.300000
# 6                            Udgået Model              753.583333
# 7      Ødelagt af lommefyld med restværdi             1351.000000
# 8     Ødelagt af lommefyld uden restværdi             1064.421053
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                     997.778837       57.731808              57.731808
# 1                     597.238095       27.333333              27.333333
# 2                      81.000000        2.000000               2.000000
# 3                     754.695142       22.192630              22.192630
# 4                     435.666667       19.000000              19.000000
# 5                     958.300000       34.250000              34.250000
# 6                     753.583333       39.029762              39.029762
# 7                    1351.000000       69.000000              69.000000
# 8                    1064.421053       67.710526              67.710526
#
#    Antal kasseret
# 0          3147.0
# 1            21.0
# 2             1.0
# 3           597.0
# 4             3.0
# 5            20.0
# 6           336.0
# 7             1.0
# 8            38.0

# %% [markdown]
# ## 10.

# %%
product_name = "09813 T-Shirt Vask"  # change to any product
subset = all_data[all_data["Produkt - Produkt"] == product_name]



plt.figure(figsize=(8, 8))

wedges, texts, autotexts = plt.pie(
    pie_data,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.7
)

plt.legend(
    wedges,
    pie_data.index,
    title="Discard reason",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(f"Discard reasons for\n{product_name}")
plt.axis("equal")
plt.tight_layout()
plt.show()

pie_data = (
    subset
    .groupby("Kassationsårsag (ui)")["Stk. tøj per kassationsdato"]
    .sum()
)
print(pie_data)
# Out:
# Kassationsårsag (ui)
# Alm.slid uden restværdi           19
# BTS fejl uden restværdi          557
# Kass. af RETUR,MINIMU,afmeld    3033
# Udgået Model                     172
# Name: Stk. tøj per kassationsdato, dtype: int64

# %%
df_p = all_data[all_data["Produkt - Produkt"] == product_name]
summary_reason = (
    df_p
    .groupby("Kassationsårsag (ui)")
    .apply(
        lambda g: pd.Series({
            # lifetime
            "Avg dage i cirkulation": g["Dage i cirkulation"].mean(),
            "Vægtet avg dage i cirkulation": np.average(
                g["Dage i cirkulation"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # washes
            "Avg total vask": g["Total antal vask"].mean(),
            "Vægtet avg total vask": np.average(
                g["Total antal vask"],
                weights=g["Stk. tøj per kassationsdato"]
            ),

            # volume
            "Antal kasseret": g["Stk. tøj per kassationsdato"].sum()
        })
    )
    .reset_index()
)

summary_reason
# Out:
# /var/folders/hk/1lkjzp1125ncvtglzw709bz40000gn/T/ipykernel_45799/1726214476.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#            Kassationsårsag (ui)  Avg dage i cirkulation  \
# 0       Alm.slid uden restværdi              263.947368
# 1       BTS fejl uden restværdi              986.229803
# 2  Kass. af RETUR,MINIMU,afmeld             1358.165183
# 3                  Udgået Model               64.610465
#
#    Vægtet avg dage i cirkulation  Avg total vask  Vægtet avg total vask  \
# 0                     263.947368        6.157895               6.157895
# 1                     986.229803        9.881508               9.881508
# 2                    1358.165183        8.715463               8.715463
# 3                      64.610465        0.127907               0.127907
#
#    Antal kasseret
# 0            19.0
# 1           557.0
# 2          3033.0
# 3           172.0
