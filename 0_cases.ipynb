# %%
from dataloader import samlet_df
# Out:
# Kategori
# Bukser        78205
# T-shirt       75099
# Jakke         20885
# Skjorte       18077
# Overall       11643
# Langærmet     11155
# Busseron       7218
# Kokkejakke     5831
# Andet          5661
# Fleece         4370
# Forklæde       3360
# Kittel         2868
# Shorts         2163
# Strømper        730
# Name: count, dtype: int64

# %% [markdown]
# Antal observationer hvor antal dage i cirkulation er 0

# %%
zero_cases_df = (
    samlet_df[(samlet_df["Dage i cirkulation"] == 0 )]
)
len(zero_cases_df)
# Out:
# 13285
